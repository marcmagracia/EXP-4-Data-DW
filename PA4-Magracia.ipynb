# %% [markdown]
# ## EXPERIMENT 4: DATA WRANGLING AND DATA VISUALIZATION
# ### _Magracia, Marc Reggie Sean S.   |   2ECE-C  |  September 17, 2024_
# Instructions: _Write a Python script/code in the Jupyter Notebook to do the given problems. You may submit your Jupyter notebook in the dedicated submission bin._

# %%
# For accessing Pandas library
import pandas as pd

# %%
df = pd.read_csv('board2.csv')
df
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
# Example
# File Name: Vis = [“Name”, “Gender”, “Track”, “Math<70”]; hometown is constant as Visayas
instru_df = df.loc[(df['Hometown'] == 'Visayas')
& (df['Math'] < 70)][['Name', 'Track', 'Gender','Math']]
instru_df
# Out:
#    Name            Track  Gender  Math
# 3    S4  Instrumentation    Male    65
# 10  S11    Communication  Female    48
# 21  S22    Communication  Female    64

# %%
# Dataframe 1
# File Name: Instru = [“Name”, “GEAS”, “Electronics >70”]; 
# track = Instrumentation, hometown = Luzon 
Instru = df.loc[(df['Track'] == 'Instrumentation') 
            & (df['Hometown'] == 'Luzon')
            & (df['Electronics'] > 70)][['Name', 'GEAS', 'Electronics']]
Instru
# Out:
#    Name  GEAS  Electronics
# 0    S1    75           89
# 7    S8    64           81
# 29  S30    57           81

# %%
# Dataframe 2
# File Name: Mindy = [ “Name”, “Track”, “Electronics”, “Average >=55”]; 
# hometown = Mindanao, gender = Female 
Mindy = df[(df['Hometown'] == 'Mindanao') 
        & (df['Gender'] == 'Female')
        & (df['Average'] > 54)][['Name', 'Track', 'Electronics', 'Average']]
Mindy
# Out:
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %%
# Visualization
import matplotlib.pyplot as plt

# %%
# Relationship of Gender and Average Scores
plt.figure(figsize=(4, 4))
plt.bar(df['Gender'], df['Average'])
plt.show()

# %%
# Relationship between Track and Average 
plt.figure(figsize=(8, 6))
df.boxplot('Average', 'Track')
plt.show()

# %%
# Relationship of Hometown and Average Score
plt.plot(hometowns, hometown_averages)
plt.show()
